# %% [markdown]
# # Dataset analysis:
# This dataset is all about the campaign for marketting from Portugal Bank where the employees are aiming to promote their term deposits by contacting them by using the details of the clients.After all these their target is "yes" if they agreed for term deposit otherwise "no".

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
import matplotlib.pyplot as mp

# %%
warnings.filterwarnings("ignore")

# %%
a=pd.read_csv("C:\\Users\\sowmy\\Downloads\\Paper1(2)\\bank.csv",delimiter=";")

# %%
df=pd.DataFrame(a)
df
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %% [markdown]
# # Missing value

# %%
df.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
import seaborn as sns
sns.pairplot(df)

# %%
df.duplicated().sum()
# Out:
# 12

# %%
df=df.drop_duplicates()
df.duplicated().sum()
# Out:
# 0

# %%
pd.set_option('display.max_columns', 81)
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  duration  campaign  pdays  previous     poutcome  \
# 0   may         mon       261         1    999         0  nonexistent
# 1   may         mon       149         1    999         0  nonexistent
# 2   may         mon       226         1    999         0  nonexistent
# 3   may         mon       151         1    999         0  nonexistent
# 4   may         mon       307         1    999         0  nonexistent
#
#    emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# ...

# %%
pd.set_option('display.max_columns', 81)
df.tail()
# Out:
#        age          job  marital            education default housing loan  \
# 41183   73      retired  married  professional.course      no     yes   no
# 41184   46  blue-collar  married  professional.course      no      no   no
# 41185   56      retired  married    university.degree      no     yes   no
# 41186   44   technician  married  professional.course      no      no   no
# 41187   74      retired  married  professional.course      no     yes   no
#
#         contact month day_of_week  duration  campaign  pdays  previous  \
# 41183  cellular   nov         fri       334         1    999         0
# 41184  cellular   nov         fri       383         1    999         0
# 41185  cellular   nov         fri       189         2    999         0
# 41186  cellular   nov         fri       442         1    999         0
# 41187  cellular   nov         fri       239         3    999         1
#
#           poutcome  emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
label = le.fit_transform(df['contact'])
label
df["contact"]=label

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
label = le.fit_transform(df['y'])
label
df["y"]=label

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
label = le.fit_transform(df['default'])
label
df["default"]=label

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
label = le.fit_transform(df['poutcome'])
label
df["poutcome"]=label

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
label = le.fit_transform(df['marital'])
label
df["marital"]=label

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
label = le.fit_transform(df['job'])
label
df["job"]=label

# %%
le = LabelEncoder()
label = le.fit_transform(df['education'])
label
df["education"]=label

# %%
df=df.drop(["day_of_week"],axis=1)
df=df.drop(["housing"],axis=1)
df=df.drop(["loan"],axis=1)
df=df.drop(["age"],axis=1)
df=df.drop(["month"],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12668/1789825484.py in <module>
#       1 # df=df.drop(["day_of_week"],axis=1)
# ----> 2 df=df.drop(["housing"],axis=1)
#       3 df=df.drop(["loan"],axis=1)
#       4 df=df.drop(["age"],axis=1)
#       5 df=df.drop(["month"],axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...

# %%
df["job"].value_counts()
# Out:
# 0     10419
# 1      9253
# 9      6739
# 7      3967
# 4      2924
# 5      1718
# 2      1456
# 6      1421
# 3      1060
# 10     1014
# 8       875
# 11      330
# Name: job, dtype: int64

# %%
df
# Out:
#        job  marital  education  default  contact  duration  campaign  pdays  \
# 0        3        1          0        0        1       261         1    999
# 1        7        1          3        1        1       149         1    999
# 2        7        1          3        0        1       226         1    999
# 3        0        1          1        0        1       151         1    999
# 4        7        1          3        0        1       307         1    999
# ...    ...      ...        ...      ...      ...       ...       ...    ...
# 41183    5        1          5        0        0       334         1    999
# 41184    1        1          5        0        0       383         1    999
# 41185    5        1          6        0        0       189         2    999
# 41186    9        1          5        0        0       442         1    999
# 41187    5        1          5        0        0       239         3    999
#
# ...

# %%
df.corr().style.background_gradient(cmap="PuBuGn_r")
# Out:
# <style type="text/css">
# #T_ee00a_row0_col0, #T_ee00a_row1_col1, #T_ee00a_row2_col2, #T_ee00a_row3_col3, #T_ee00a_row4_col4, #T_ee00a_row5_col5, #T_ee00a_row6_col6, #T_ee00a_row7_col7, #T_ee00a_row8_col8, #T_ee00a_row9_col9, #T_ee00a_row10_col10, #T_ee00a_row11_col11, #T_ee00a_row12_col12, #T_ee00a_row13_col13, #T_ee00a_row14_col14, #T_ee00a_row15_col15 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_ee00a_row0_col1, #T_ee00a_row8_col9 {
#   background-color: #016755;
#   color: #f1f1f1;
# }
# #T_ee00a_row0_col2, #T_ee00a_row4_col3, #T_ee00a_row7_col4 {
#   background-color: #0b8393;
#   color: #f1f1f1;
# }
# #T_ee00a_row0_col3, #T_ee00a_row15_col12 {
#   background-color: #016d5c;
#   color: #f1f1f1;
# }
# #T_ee00a_row0_col4, #T_ee00a_row0_col11, #T_ee00a_row2_col12, #T_ee00a_row4_col15, #T_ee00a_row5_col4 {
#   background-color: #017164;
#   color: #f1f1f1;
# }
# #T_ee00a_row0_col5, #T_ee00a_row12_col5, #T_ee00a_row12_col6 {
#   background-color: #015846;
# ...

# %%
df.columns
# Out:
# Index(['job', 'marital', 'education', 'default', 'contact', 'duration',
#        'campaign', 'pdays', 'previous', 'poutcome', 'emp.var.rate',
#        'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
df
# Out:
#        job  marital  education  default  contact  duration  campaign  pdays  \
# 0        3        1          0        0        1       261         1    999
# 1        7        1          3        1        1       149         1    999
# 2        7        1          3        0        1       226         1    999
# 3        0        1          1        0        1       151         1    999
# 4        7        1          3        0        1       307         1    999
# ...    ...      ...        ...      ...      ...       ...       ...    ...
# 41183    5        1          5        0        0       334         1    999
# 41184    1        1          5        0        0       383         1    999
# 41185    5        1          6        0        0       189         2    999
# 41186    9        1          5        0        0       442         1    999
# 41187    5        1          5        0        0       239         3    999
#
# ...

# %%
a=df.duration.mean()
# Out:
# 258.3158150378861

# %%
def duration(data):
    df.loc[data['duration'] <= 102, 'duration'] = 1
    df.loc[(data['duration'] > 102) & (df['duration'] <= 319)  , 'duration'] = 2
    df.loc[(data['duration'] > 319) & (df['duration'] <= 645), 'duration'] = 3
    df.loc[data['duration']  > 645, 'duration'] = 4
    return df
duration(df);

# %%
df
# Out:
#        job  marital  education  default  contact  duration  campaign  pdays  \
# 0        3        1          0        0        1         1         1    999
# 1        7        1          3        1        1         1         1    999
# 2        7        1          3        0        1         1         1    999
# 3        0        1          1        0        1         1         1    999
# 4        7        1          3        0        1         1         1    999
# ...    ...      ...        ...      ...      ...       ...       ...    ...
# 41183    5        1          5        0        0         1         1    999
# 41184    1        1          5        0        0         1         1    999
# 41185    5        1          6        0        0         1         2    999
# 41186    9        1          5        0        0         1         1    999
# 41187    5        1          5        0        0         1         3    999
#
# ...

# %%
x=df.drop(['y'],axis=1)
y=df['y']

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
log_classifier =  LogisticRegression()
sv_classifier = SVC()
ada_classifier=AdaBoostClassifier()
naive_classifier=GaussianNB()
random_classifier=RandomForestClassifier()
knn_classifier=KNeighborsClassifier()

# %%
def classifiers(clf1, clf2, clf3,clf4,clf5,clf6, X_train, y_train):    
    # A list of all classifiers
    clfs = [clf1, clf2, clf3,clf4,clf5,clf6]
    
    # An empty list to comprehend 
    all_clfs_acc = []
    
    # Train each classifier, evaluate it on the training set 
    # And append the accuracy to 'all_clfs_acc' 
    
    for clf in clfs:
        
        clf.fit(X_train, y_train)
        preds = clf.predict(X_train)
        acc = accuracy_score(y_train,preds)
        acc = acc.tolist()
        all_clfs_acc.append(acc)
#         classification_report(y_test,y_pred)
        
    return all_clfs_acc

# %%
a=classifiers(log_classifier,sv_classifier,ada_classifier, naive_classifier,random_classifier ,knn_classifier,x_train, y_train)

# %%
a=pd.DataFrame(a)
b=pd.Index(["logistic","SVC","ADABOOST","NAIVE BAYES","RANDOM FOREST","KNN"])
a.set_index(b)
# Out:
#                       0
# logistic       0.900546
# SVC            0.903127
# ADABOOST       0.900577
# NAIVE BAYES    0.832058
# RANDOM FOREST  0.966454
# KNN            0.913206

# %% [markdown]
# # Random forest shows high accuracy than any other models hence we will use random forest as a good model

# %%
from sklearn.model_selection import cross_val_score

# %%
cross_val_score(LogisticRegression(solver='liblinear',multi_class='ovr'), x,y,cv=3)
# Out:
# array([0.88729419, 0.89034608, 0.25726776])

# %%
cross_val_score(SVC(gamma='auto'), x,y,cv=3)
# Out:
# array([0.88729419, 0.18703097, 0.25078324])

# %%
cross_val_score(RandomForestClassifier(n_estimators=40),x,y,cv=3)
# Out:
# array([0.88765846, 0.05989071, 0.14863388])
